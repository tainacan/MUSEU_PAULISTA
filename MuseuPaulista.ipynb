# %%
import dbfread
import pandas as pd
import numpy as np

#https://readthedocs.org/projects/dbfread/downloads/pdf/latest/

# %%
table = dbfread.DBF('Banco dados original/objetos.dbf', load=True)
frame = pd.DataFrame(iter(table))
frame
# Out:
#                         CODIGO CLASSE SUBCLASSE     CODIGO2  \
# 0      1-01-01-001-00001-00-00     01      0101  00001-0001
# 1      1-01-01-001-00002-00-00     01      0101  00001-0002
# 2      1-01-01-001-00003-00-00     01      0101  00001-0003
# 3      1-01-01-001-00004-00-00     01      0101  00001-0004
# 4      1-01-01-001-00005-00-00     01      0101  00001-0005
# ...                        ...    ...       ...         ...
# 30625  1-07-01-000-03075-00-00     07      0701
# 30626  1-07-01-000-03076-00-00     07      0701
# 30627  1-07-01-000-03077-00-00     07      0701
# 30628  1-07-01-000-03078-00-00     07      0701
# 30629  1-07-01-000-03079-00-00     07      0701
#
#                     DENOM IGRUPO ISUBGRUPO VERNACULAR ACESSORIOS  ORIGEM  ...  \
# 0                640 RÉIS     01                                  BRASIL  ...
# 1      640 RÉIS - 1º TIPO     01                                  BRASIL  ...
# ...

# %%
list(frame.columns)
# Out:
# ['CODIGO',
#  'CLASSE',
#  'SUBCLASSE',
#  'CODIGO2',
#  'DENOM',
#  'IGRUPO',
#  'ISUBGRUPO',
#  'VERNACULAR',
#  'ACESSORIOS',
#  'ORIGEM',
#  'PERIODO1',
#  'PERIODO',
#  'OUTROS_P',
#  'SECULO',
#  'FASE1',
#  'FASE',
#  'DECADA',
#  'DATA',
#  'ESTILO',
#  'COD_FABR',
#  'FABRICANTE',
#  'CASA_COML',
#  'MARCA_MOD',
#  'SERIE',
#  'FUNDO',
#  'COLECAO',
#  'TEMATICA',
#  'CONJUNTO',
#  'LOCAL_PERM',
#  'LOCAL_PER2',
#  'LOCAL_TEMP',
#  'FUNCAO',
#  'NEGATIVO',
#  'MAT_TECNIC',
#  'ALTURA',
#  'ALTURA1',
#  'LARG',
#  'LARG1',
#  'COMPR',
#  'COMPR1',
#  'DIAM_MOD',
#  'DIAM_MOD1',
#  'PESO',
#  'PESO1',
#  'ESPESSURA',
#  'PROF',
#  'CALIBRE',
#  'UCOMPR',
#  'UMASSA',
#  'DESCRICAO',
#  'HISTORICO',
#  'EST_CONS',
#  'ACESSO',
#  'NMP',
#  'NRUSP',
#  'NPROCESS',
#  'NANT',
#  'DENOM_ANT',
#  'TIPO_AQUIS',
#  'TIPO_AQUI2',
#  'FONTE',
#  'TERM_AQUIS',
#  'COLETOR',
#  'DATA_AQUIS',
#  'MOEDA',
#  'MOEDA1',
#  'VAL_AQUIS',
#  'AVAL_DOLAR',
#  'DATA_AVAL',
#  'AVALIADOR',
# ...

# %%
#Checar o tamanho da string da coluna descricao
frame.DESCRICAO.str.len().max()
# Out:
# 4507.0

# %%
frame.DESCRICAO[0]
# Out:
# 'ANV/ NA ORLA: "PETRVS.II.D.G.PORT.ET.BRAS.D.". NO CAMPO, ESCUDO ENCIMADO POR COROA MÉDIA, LADEADA PELA DATA: 16-95".  À ESQUERDA  DO ESCUDO APARECE O VALOR: "640" E A DIREITA, TRES FLORÕES.\r\n\r\nREV/ NA ORLA: "SUBQ SIGN NATA STAB". NO CAMPO, ESFERA ARMILAR SOBRE A CRUZ DA ORDEM DE CRISTO.\r\n\r\nCASA DA MOEDA DA BAHIA, SEM LETRA MONETÁRIA.\r\nORLA LISA COM DENTEAÇÃO SINGELA. SERRILHA ENCORDOADA'
